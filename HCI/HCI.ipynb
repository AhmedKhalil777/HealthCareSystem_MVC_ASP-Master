# %% [markdown]
# # In The Name Of ALLAH
# ---
#
# ## HCI Documentation (Dr : Mohammad Seyam)
#
# ---
#
# ## Functional & Non Functional Requirments
#
#  - ![](../PIC/17.PNG)
#  - ![](../PIC/18.PNG)
#  - ![](../PIC/19.PNG)
#  - ![](../PIC/20.PNG)
#
# ---
#
# ## Personas
#
#  - ![](../PIC/21.PNG)
#  - ![](../PIC/22.PNG)
#  - ![](../PIC/23.PNG)
#
# ---
#
# ## Use Stories
#
#  - ![](../PIC/24.PNG)
#  - ![](../PIC/25.PNG)
#  - ![](../PIC/26.PNG)
#
# ---
#
# ## Scenarios
#
#  - ![](../PIC/27.PNG)
#  - ![](../PIC/28.PNG)
#
# ---
# ## WireFrames
#  - ![](../PIC/29.png)
#  - ![](../PIC/30.png)
#  - ![](../PIC/31.png)
#  - ![](../PIC/32.png)
#  - ![](../PIC/33.png)
#  - ![](../PIC/34.png)
#  - ![](../PIC/35.png)
#  - ![](../PIC/36.png)
#  - ![](../PIC/37.png)
#  - ![](../PIC/38.png)
#  - ![](../PIC/39.png)
#  - ![](../PIC/40.png)
#  - ![](../PIC/41.png)
#  - ![](../PIC/42.png)
#  - ![](../PIC/43.png)
#  - ![](../PIC/44.png)
#  - ![](../PIC/45.png)
#  - ![](../PIC/46.png)
#
# ---
#
# ## Sketches & StoryBoard
#
#  - ![](../PIC/53.png)
#  - ![](../PIC/52.png)
#  - ![](../PIC/51.png)
#  - ![](../PIC/50.png)
#  - ![](../PIC/49.png)
#  - ![](../PIC/48.png)
#  - ![](../PIC/47.png)
